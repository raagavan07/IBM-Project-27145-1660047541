# %% [markdown]
# Emoji Python Package

# %%
# !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from emoji import emojize
print(emojize(":thumbs_up:"))
# Out:
# 👍

# %% [markdown]
# Wikipedia Python Package

# %%
# !pip install wikipedia
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import wikipedia
print (wikipedia.random(pages=1))
# Out:
# Aalaporaan Thamizhan

# %% [markdown]
# Urllib Python Package

# %%
from urllib.request import urlopen
print (urlopen("https://careereducation.smartinternz.com/").read())
# Out:
# b'<!DOCTYPE html>\r\n<html lang="zxx">\r\n<meta http-equiv="content-type" content="text/html;charset=UTF-8" />\r\n\r\n<head>\r\n    <!-- <link rel="shortcut icon" type="image/x-icon" href="https://careereducation.smartinternz.com/assets/blank_thumb.png"> -->\r\n    <meta name="p:domain_verify" content="55c4ec39b8d9f7a35b5fafcd164c516d" />\r\n\r\n    <meta property="og:title" content="Professional Readiness for Innovation, Employability and Entrepreneurship" />\r\n    <meta property="og:url" content="https://careereducation.smartinternz.com/" />\r\n    <meta property="og:description" content="Team2Solve and Code2Build">\r\n    <meta property="og:image" content="https://careereducation.smartinternz.com/assets/blank_thumb.png">\r\n\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\r\n    <!-- Google Tag Manager -->\r\n    <script>\r\n        (function(w, d, s, l, i) {\r\n            
# ...

# %% [markdown]
# Pyaztro Python Package

# %%
# !pip install pyaztro
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pyaztro
pyaztro.Aztro(sign='gemini').description
# Out:
# "You're still feeling exhilarated and enthusiastic, and quite ready to do what it takes to accomplish something you've wanted to do for a very long time. Don't lose that feeling. Stage one was recognizing your dream. Put stage two into operation now."

# %% [markdown]
# Art Python Package

# %%
# !pip install art
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 592 kB 5.1 MB/s
# ...

# %%
from art import *
tprint("IBM")
# Out:
#  ___  ____   __  __
# |_ _|| __ ) |  \/  |
#  | | |  _ \ | |\/| |
#  | | | |_) || |  | |
# |___||____/ |_|  |_|
